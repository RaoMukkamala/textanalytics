# %%
textFilePath = '/data/chesterton-brown.txt'
with open(textFilePath) as f:
    text = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d10f1b2875db> in <module>()
#       1 textFilePath = '/data/chesterton-brown.txt'
# ----> 2 with open(textFilePath) as f:
#       3     text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/chesterton-brown.txt'

# %%
import os

currentDir = os.getcwd()

textFilePath = os.path.join(currentDir, 'data', 'chesterton-brown.txt')


with open(textFilePath) as f:
    text = f.read()

# read a file line by line
with open(textFilePath) as f:
    lines = f.readlines()

# reading the first line
lines[0]

#reading the last line
lines[-1]

# reading first 15 lins
lines[0:15]

# reading last 15 lins
lines[-15:]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c837ea6929d5> in <module>()
#       6
#       7
# ----> 8 with open(textFilePath) as f:
#       9     text = f.read()
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/raghava/data-analytics Dropbox/Raghava Rao Mukkamala/cbs-research/teaching/2018-IMT-G-Short-course/git-repo/textanalytics/data/chesterton-brown.txt'

# %%
import os

currentDir = os.getcwd()

textFilePath = path.join(currentDir, 'data', 'shakespeare-macbeth.txt')


with open(textFilePath) as f:
    text = f.read()

# read a file line by line
with open(textFilePath) as f:
    lines = f.readlines()

# reading the first line
lines[0]

#reading the last line
lines[-1]

# reading first 15 lins
lines[0:15]

# reading last 15 lins
lines[-15:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-764b3713d836> in <module>()
#       3 currentDir = os.getcwd()
#       4
# ----> 5 textFilePath = path.join(currentDir, 'data', 'shakespeare-macbeth.txt')
#       6
#       7
#
# NameError: name 'path' is not defined

# %%
import os

currentDir = os.getcwd()

textFilePath = os.path.join(currentDir, 'data', 'shakespeare-macbeth.txt')


with open(textFilePath) as f:
    text = f.read()

# read a file line by line
with open(textFilePath) as f:
    lines = f.readlines()

# reading the first line
lines[0]

#reading the last line
lines[-1]
# Out:
# 'FINIS. THE TRAGEDIE OF MACBETH.\n'

# %%
text
# Out:
# "[The Tragedie of Macbeth by William Shakespeare 1603]\n\n\nActus Primus. Scoena Prima.\n\nThunder and Lightning. Enter three Witches.\n\n  1. When shall we three meet againe?\nIn Thunder, Lightning, or in Raine?\n  2. When the Hurley-burley's done,\nWhen the Battaile's lost, and wonne\n\n   3. That will be ere the set of Sunne\n\n   1. Where the place?\n  2. Vpon the Heath\n\n   3. There to meet with Macbeth\n\n   1. I come, Gray-Malkin\n\n   All. Padock calls anon: faire is foule, and foule is faire,\nHouer through the fogge and filthie ayre.\n\nExeunt.\n\n\nScena Secunda.\n\nAlarum within. Enter King Malcome, Donalbaine, Lenox, with\nattendants,\nmeeting a bleeding Captaine.\n\n  King. What bloody man is that? he can report,\nAs seemeth by his plight, of the Reuolt\nThe newest state\n\n   Mal. This is the Serieant,\nWho like a good and hardie Souldier fought\n'Gainst my Captiuitie: Haile braue friend;\nSay to the King, the knowledge of the Broyle,\nAs thou didst leaue it\n\n   Cap
# ...

# %%
lines
# Out:
# ['[The Tragedie of Macbeth by William Shakespeare 1603]\n',
#  '\n',
#  '\n',
#  'Actus Primus. Scoena Prima.\n',
#  '\n',
#  'Thunder and Lightning. Enter three Witches.\n',
#  '\n',
#  '  1. When shall we three meet againe?\n',
#  'In Thunder, Lightning, or in Raine?\n',
#  "  2. When the Hurley-burley's done,\n",
#  "When the Battaile's lost, and wonne\n",
#  '\n',
#  '   3. That will be ere the set of Sunne\n',
#  '\n',
#  '   1. Where the place?\n',
#  '  2. Vpon the Heath\n',
#  '\n',
#  '   3. There to meet with Macbeth\n',
#  '\n',
#  '   1. I come, Gray-Malkin\n',
#  '\n',
#  '   All. Padock calls anon: faire is foule, and foule is faire,\n',
#  'Houer through the fogge and filthie ayre.\n',
#  '\n',
#  'Exeunt.\n',
#  '\n',
#  '\n',
#  'Scena Secunda.\n',
#  '\n',
#  'Alarum within. Enter King Malcome, Donalbaine, Lenox, with\n',
#  'attendants,\n',
#  'meeting a bleeding Captaine.\n',
#  '\n',
#  '  King. What bloody man is that? he can report,\n',
# ...

# %%
import os

currentDir = os.getcwd()

sourceFile = os.path.join(currentDir, 'data', 'Hillary_1000000_lines.csv')


#sourceFile = '/Users/raghava/Downloads/FullRawFile_HillaryClinton_20.csv'

destinationPath = os.path.join(currentDir, 'data', 'Hillary_50000_lines.csv')

with open(destinationPath, 'w') as fw:
   with open(sourceFile) as fr:
      for i in range(50000):
         fw.write(fr.readline())

# %%
import os
import csv

currentDir = os.getcwd()

sourceFile = os.path.join(currentDir, 'data', 'Hillary_50000_lines.csv')


destinationPath = os.path.join(currentDir, 'data', 'Hillary_50000_lines_transformed.csv')



with open(sourceFile) as csvfile:
   fbDataReader = csv.reader(csvfile, delimiter=',',)
   with open(targetFile, 'w', newline='') as writeFile:
      fbTextWriter = csv.writer(writeFile, delimiter=';',quoting=csv.QUOTE_MINIMAL)
      for row in fbDataReader:
         print(str(len(row)))
         if len(row) != 20: 
            continue
         row[19] = row[19].replace(';',' ')
         fbTextWriter.writerow(row)

   writeFile.close()

print('done!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b7d29cc40902> in <module>()
#      13 with open(sourceFile) as csvfile:
#      14    fbDataReader = csv.reader(csvfile, delimiter=',',)
# ---> 15    with open(targetFile, 'w', newline='') as writeFile:
#      16       fbTextWriter = csv.writer(writeFile, delimiter=';',quoting=csv.QUOTE_MINIMAL)
#      17       for row in fbDataReader:
#
# NameError: name 'targetFile' is not defined

# %%
import os
import csv

currentDir = os.getcwd()

sourceFile = os.path.join(currentDir, 'data', 'Hillary_50000_lines.csv')


destinationPath = os.path.join(currentDir, 'data', 'Hillary_50000_lines_transformed.csv')



with open(sourceFile) as csvfile:
   fbDataReader = csv.reader(csvfile, delimiter=',',)
   with open(destinationPath, 'w', newline='') as writeFile:
      fbTextWriter = csv.writer(writeFile, delimiter=';',quoting=csv.QUOTE_MINIMAL)
      for row in fbDataReader:
         print(str(len(row)))
         if len(row) != 20: 
            continue
         row[19] = row[19].replace(';',' ')
         fbTextWriter.writerow(row)

   writeFile.close()

print('done!')
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# ...

# %%
from textblob import TextBlob
